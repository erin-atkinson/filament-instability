# %%
include("src/figures.jl")
# Out:
# friction_terms (generic function with 1 method)

# %%
runnames = ["Ro08Ri000Ek0A15", "Ro08Ri001Ek0A15_1", "Ro08Ri010Ek0A15", "Ro08Ri020Ek0A15"]
runtitles = [L"0.0", L"0.01", L"0.1", L"0.2"];
#buoyancy_plots(runnames[2], 501)

# %%
down_front_velocity_plots(runnames[2], 301)

# %%
shear_production_plots(runnames[2], 501)

# %%
integrated_vshear(runnames[1])

# %%
integrated_vshear(runnames[2])

# %%
integrated_vshear(runnames[3])

# %%
integrated_vshear(runnames[4])
